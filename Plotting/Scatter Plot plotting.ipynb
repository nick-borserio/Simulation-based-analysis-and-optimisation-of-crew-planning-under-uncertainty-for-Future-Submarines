# %%
#Scatter Plot Combined Rec and Prom
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import os
TP1Cost=[137512.58652281598,192655.87126057397, 263127.94776014576, 282348.7006869887, 94808.33153392162,128155.70856893089]
TP1Avail=[0.773955773955774,0.6774193548387097,0.5844155844155844,0.5635062611806798,0.8694444444444445,0.773955773955774]
TP2Cost=[140042.01132881411,193173.88743599533,263470.0776193811,282435.72503501247,94816.72010218674,140181.6365080714]
TP2Avail=[0.85995085995086,0.7526881720430108,0.6493506493506493,0.6261180679785331,0.9722222222222222,0.8378378378378378]
TP3Cost=[140294.7060372314,194402.6433059663,264761.71803324675,283952.625531222,95546.78369240438,127132.43545001454]
TP3Avail=[0.7985257985257985,0.6989247311827957,0.6029684601113172,0.5813953488372092,0.9027777777777778,0.7985257985257985]

for i in range(len(TP1Cost)):
    TP1Cost[i]=(TP1Cost[i]/40)
    TP2Cost[i]=(TP2Cost[i]/40)
    TP3Cost[i]=(TP3Cost[i]/40)
    TP1Avail[i]=(TP1Avail[i]*100)
    TP2Avail[i]=(TP2Avail[i]*100)
    TP3Avail[i]=(TP3Avail[i]*100)
    

#generate a list of markers ad another of colors 
markers = ["." , "," , "o" , 'P' , "x" , "d"]
colors = ['r','g','b','c','m', 'y', 'k']
legend1=["TP1-Transition Plan 1","TP1-Transition Plan 2","TP1-Transition Plan 3","TP1-Increase Fleet","TP1-Stop 2040","TP1-Double Seperation"]
legend2=["TP2-Transition Plan 1","TP2-Transition Plan 2","TP2-Transition Plan 3","TP2-Increase Fleet","TP2-Stop 2040","TP2-Double Seperation"]
legend3=["TP3-Transition Plan 1","TP3-Transition Plan 2","TP3-Transition Plan 3","TP3-Increase Fleet","TP3-Stop 2040","TP3-Double Seperation"]
#make a sample dataset
from matplotlib.pyplot import figure

figure(figsize=(10, 8), dpi=80)

for i in range(len(TP1Cost)):
    mi = 's' #marker
    xi = TP1Avail[i] 
    yi = TP1Cost[i] 
    ci = colors[i] #colour
    plt.scatter(xi,yi,marker=mi, color=ci,label=legend1[i]) 
    plt.legend()
for i in range(len(TP2Cost)): 
    mi = '^' #marker for feature 
    xi = TP2Avail[i] 
    yi = TP2Cost[i] 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci,label=legend2[i])
    plt.legend()
for i in range(len(TP3Cost)): #for each of the 7 features 
    mi = 'x' #marker for feature 
    xi = TP3Avail[i] 
    yi = TP3Cost[i] 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci,label=legend3[i])
    plt.legend() 
    plt.title('Combined Recruitment and Promotion Policy Optimisation')
    plt.xlabel('Average Availability')
    plt.ylabel('Cost ($ Million)')
    plt.xlim([50, 105])
    plt.ylim([2000, 8000])
filename='combScatter'
i = 0 
while True:
    i += 1
    newname = '{}{:d}.png'.format(filename, i)
    if os.path.exists(newname):
        continue
    plt.savefig(newname)
    break    
plt.show()

# %%
#Scatter Plot Combined Rec and Prom
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
import os
TP1Cost=[151978.77700568896,176220.55643608834,243607.55257772666,262231.66151783004,149682.507173664,214404.9548250583]
TP1Avail=[0.9680589680589681,0.8731182795698924, 0.7551020408163265, 0.7280858676207513, 0.9944444444444445,0.8058968058968059]
TP2Cost=[142086.49674720067,176886.26748141943,245524.19461858022,264241.0368314843,139835.21641665237,196857.04697621416]
TP2Avail=[0.9656019656019657,0.8516129032258064,0.7346938775510204,0.7084078711985689, 0.9916666666666667,0.8181818181818181]
TP3Cost=[158928.26080568897,183170.04023608836,250557.03637772665,269181.14531783,156631.990973664,221354.4386250583]
TP3Avail=[0.9680589680589681,0.8731182795698924,0.7551020408163265,0.7280858676207513,0.9944444444444445,0.8058968058968059]

for i in range(len(TP1Cost)):
    TP1Cost[i]=(TP1Cost[i]/40)
    TP2Cost[i]=(TP2Cost[i]/40)
    TP3Cost[i]=(TP3Cost[i]/40)
    TP1Avail[i]=(TP1Avail[i]*100)
    TP2Avail[i]=(TP2Avail[i]*100)
    TP3Avail[i]=(TP3Avail[i]*100)
    

#generate a list of markers ad another of colors 
markers = ["." , "," , "o" , 'P' , "x" , "d"]
colors = ['r','g','b','c','m', 'y', 'k']
legend1=["TP1-Transition Plan 1","TP1-Transition Plan 2","TP1-Transition Plan 3","TP1-Increase Fleet","TP1-Stop 2040","TP1-Double Seperation"]
legend2=["TP2-Transition Plan 1","TP2-Transition Plan 2","TP2-Transition Plan 3","TP2-Increase Fleet","TP2-Stop 2040","TP2-Double Seperation"]
legend3=["TP3-Transition Plan 1","TP3-Transition Plan 2","TP3-Transition Plan 3","TP3-Increase Fleet","TP3-Stop 2040","TP3-Double Seperation"]
#make a sample dataset
from matplotlib.pyplot import figure

figure(figsize=(10, 8), dpi=80)

for i in range(len(TP1Cost)):
    mi = 's' #marker
    xi = TP1Avail[i] 
    yi = TP1Cost[i] 
    ci = colors[i] #colour
    plt.scatter(xi,yi,marker=mi, color=ci,label=legend1[i]) 
    plt.legend()
for i in range(len(TP2Cost)): 
    mi = '^' #marker for feature 
    xi = TP2Avail[i] 
    yi = TP2Cost[i] 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci,label=legend2[i])
    plt.legend()
for i in range(len(TP3Cost)): #for each of the 7 features 
    mi = 'x' #marker for feature 
    xi = TP3Avail[i] 
    yi = TP3Cost[i] 
    ci = colors[i] #color for ith feature 
    plt.scatter(xi,yi,marker=mi, color=ci,label=legend3[i])
    plt.legend() 
    plt.title('Combined Recruitment and Promotion Policy Optimisation')
    plt.xlabel('Average Availability')
    plt.ylabel('Cost ($ Million)')
    plt.xlim([50, 105])
    plt.ylim([2000, 8000])
filename='Rec_Scatter'
i = 0 
while True:
    i += 1
    newname = '{}{:d}.png'.format(filename, i)
    if os.path.exists(newname):
        continue
    plt.savefig(newname)
    break    
plt.show()
